# %% [markdown]
# ### following steps in order:
#
# 1. Install Mediapipe hands for python
# 2. Detect hands from real time camera feed
# 3. ouput images using openCV

# %% [markdown]
# # Install and import dependencies

# %%
# !pip install mediapipe
# !pip install opencv-python

# %%
import mediapipe as mp
import cv2
import numpy as np
import uuid
import os
# Out:
# 2024-02-02 14:23:00.567640: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-02 14:23:00.797238: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-02 14:23:00.797363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-02 14:23:00.838789: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
mp_drawing=mp.solutions.drawing_utils
mp_hands=mp.solutions.hands

# %% [markdown]
# # Draw Hands
# <img src="https://developers.google.com/static/mediapipe/images/solutions/hand-landmarks.png"/>

# %%
cap = cv2.VideoCapture(0)
with mp_hands.Hands(min_detection_confidence=0.1, min_tracking_confidence=0.1,max_num_hands=1) as hands:
# Check if the webcam is opened correctly

    while cap.isOpened():
        ret, frame = cap.read()
        
        #BGR to RGB
        image=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        
        #set flag false
        image.flags.writeable=False
        
        #detections
        results=hands.process(image)
        
        #set flag to true
        image.flags.writeable=True
        
        #RGB 2 BGR
        image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
        
        #detections
        print(results.multi_hand_landmarks)
        
        #render results
        if results.multi_hand_landmarks:
            for num,hand in enumerate(results.multi_hand_landmarks):
                mp_drawing.draw_landmarks(image,hand,mp_hands.HAND_CONNECTIONS)
                
         
        cv2.imshow('SLI', image)

        if cv2.waitKey(10) & 0xFF==ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# None
# None
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# QObject::moveToThread: Current thread (0x7479a10) is not the object's thread (0x7a76940).
# Cannot move to target thread (0x7479a10)
#
# ...

# %%
print(results.multi_hand_landmarks)
